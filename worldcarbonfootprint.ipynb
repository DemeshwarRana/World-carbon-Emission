# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import pandas as pd

# %%
fig = px.colors.qualitative.swatches()
fig.show()

# %%
actual_x=[(s.x0+s.x1)/2 for s in  fig.layout.shapes]
actual_y=[(s.y0+s.y1)/2 for s in fig.layout.shapes]
sizes=[]

labels = [
    'China','India','South<br>Korea','Taiwan','Japan','Thailand','Kazakhstan', 
    'Indonesia','Pakistan','Uzbekistan', 'South<br>Africa', 'Egypt','USA','Canada', 
    'Mexico','Russia','Germany','Iran','Saudi<br>Arabia','UK','Ukraine','France', 
    'Spain', 'Australia','Brazil','Argentina','UAE','Netherland'
]
categories=[
    {'name':'Asia','color':'orange'},
    {'name':'North America','color':'rgb(166,216,84)'},
    {'name':'Middle East','color':'#B82E2E'},
    {'name':'Europe','color':'rgb(115,175,72)'},
    {'name':'Australia','color':'#19D3F3'},
{'name':'South America','color':'RGB(204,102,119)'}]
fig=go.Figure()
#China
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=150,y0=480,y1=480+132,x1=150+132,fillcolor='#FF9900'
)
#india
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=150,y0=650,y1=650+70,x1=150+70,fillcolor='#FF9900'
)
#South Korea
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=230,y0=680,y1=680+50,x1=230+50,fillcolor='#FF9900'
)
#Taiwan
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=285,y0=660,y1=660+40,x1=285+40,fillcolor='#FF9900'
)
#japan
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=283,y0=500,y1=500+70,x1=283+70,fillcolor='#FF9900'
)
#Thailand
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=274,y0=566.5,y1=566.5+40,x1=274+40,fillcolor='#FF9900'
)
#kazakhstan
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=263.5,y0=470,y1=470+40,x1=263.5+40,fillcolor='#FF9900'
)
#indonesia
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=340,y0=470,y1=470+50,x1=340+50,fillcolor='#FF9900'
)
#pakistan
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=310,y0=470,y1=470+30,x1=310+30,fillcolor='#FF9900'
)
#uzbekistan
fig.add_shape(
    type='circle',
    line=dict(color='#FF9900'),
    xref='x',yref='y',x0=238,y0=457,y1=457+30,x1=238+30,fillcolor='#FF9900'
)
#south africa
fig.add_shape(
    type='circle',
    line=dict(color='#9647BD'),
    xref='x',yref='y',x0=320,y0=600,y1=600+50,x1=320+50,fillcolor='#9647BD'
)
#EGYPT
fig.add_shape(
    type='circle',
    line=dict(color='#9647BD'),
    xref='x',yref='y',x0=360,y0=560,y1=560+30,x1=360+30,fillcolor='#9647BD'
)
#usa
fig.add_shape(
    type='circle',
    line=dict(color='rgb(166,216,84)'),
    xref='x',yref='y',x0=220,y0=102,y1=102+100,x1=220+100,fillcolor='rgb(166,216,84)'
)
#canada
fig.add_shape(
    type='circle',
    line=dict(color='rgb(166,216,84)'),
    xref='x',yref='y',x0=250,y0=203,y1=203+50,x1=250+50,fillcolor='rgb(166,216,84)'
)
#mexico
fig.add_shape(
    type='circle',
    line=dict(color='rgb(166,216,84)'),
    xref='x',yref='y',x0=297,y0=187,y1=187+40,x1=297+40,fillcolor='rgb(166,216,84)'
)
#RUSSIA
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=260,y0=253,y1=253+60,x1=260+60,fillcolor='rgb(115,175,72)'
)
#GERMANY
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=260,y0=315,y1=315+50,x1=260+50,fillcolor='rgb(115,175,72)'
)
#iran
fig.add_shape(
    type='circle',
    line=dict(color='#B82E2E'),
    xref='x',yref='y',x0=280,y0=423,y1=423+50,x1=280+50,fillcolor='#B82E2E'
)
#SAUDI ARABIA
fig.add_shape(
    type='circle',
    line=dict(color='#B82E2E'),
    xref='x',yref='y',x0=260,y0=375,y1=375+50,x1=260+50,fillcolor='#B82E2E'
)
#UK
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=301,y0=350,y1=350+40,x1=301+40,fillcolor='rgb(115,175,72)'
)
#UKRAINE
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=311,y0=390,y1=390+35,x1=311+35,fillcolor='rgb(115,175,72)'
)
#FRANCE
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=306,y0=300,y1=300+35,x1=306+35,fillcolor='rgb(115,175,72)'
)
#SPAIN
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=305,y0=228,y1=228+35,x1=305+35,fillcolor='rgb(115,175,72)'
)
#AUSTRALIA
fig.add_shape(
    type='circle',
    line=dict(color='#19D3F3'),
    xref='x',yref='y',x0=332,y0=418,y1=418+50,x1=332+50,fillcolor='#19D3F3'
)
#BRAZIL
fig.add_shape(
    type='circle',
    line=dict(color='RGB(204,102,119)'),
    xref='x',yref='y',x0=341,y0=363,y1=363+40,x1=341+40,fillcolor='RGB(204,102,119)'
)
#ARGENTINA
fig.add_shape(
    type='circle',
    line=dict(color='RGB(204,102,119)'),
    xref='x',yref='y',x0=333,y0=328,y1=328+30,x1=333+30,fillcolor='RGB(204,102,119)'
)
#UAE
fig.add_shape(
    type='circle',
    line=dict(color='#B82E2E'),
    xref='x',yref='y',x0=245,y0=420,y1=420+36,x1=245+36,fillcolor='#B82E2E'
)
#NETHER
fig.add_shape(
    type='circle',
    line=dict(color='rgb(115,175,72)'),
    xref='x',yref='y',x0=321,y0=260,y1=260+35,x1=321+35,fillcolor='rgb(115,175,72)'
)
fig.update_xaxes(visible=False)
fig.update_yaxes(visible=False)
fig.add_trace(go.Scatter(
    x=actual_x,
    y=actual_y,
    mode='text',
    text=labels,
    hovertext=sizes,
    textposition='middle center',
    textfont=dict(color='white',
                 size=10),
    showlegend=False
))
for cat in categories:
    fig.add_trace(go.Scatter(
        x=[None],y=[None],
        mode='markers',
        marker=dict(size=12,color=cat['color']),
        legendgroup=cat['name'],
        showlegend=True,
        name=cat['name']
    ))
fig.update_layout(legend=dict(
    font=dict(size=10),
    xref='paper',
    yref='paper',
    orientation='v',
    y=0.15,
    xanchor='left',
    x=-0.1
))
fig.update_layout(
    title="Global <span style='font-size:40px;'><b>Carbon</b></span> Footprint<br><sup>Which nations are leaving the deepest mark?",
    title_font=dict(size=20),
)
fig.update_layout(
    template='plotly_dark',
    shapes=[dict(layer='below')],
    xaxis=dict(range=[0,600],showgrid=False,dtick=20),
    yaxis=dict(range=[100,800],showgrid=False,dtick=20,scaleanchor='x',scaleratio=1),
    height=800,width=800
)
fig.add_annotation(
    text='<b>China</b> and <b>USA</b> together emit nealy <b>45%</b> Carbon',
    xref='paper',
    yref='paper',
    x=1.1,
    xanchor='right',
    y=-0.12,
    showarrow=False
    
)
fig.show()
